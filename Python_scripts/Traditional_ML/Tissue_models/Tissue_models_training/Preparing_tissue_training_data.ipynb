# %% [markdown]
# #Import modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# #Data

# %%
sample_annot = pd.read_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/MasterMapping_MetImmune_03_16_2022_release.csv')
sample_annot
# Out:
#           CommonID  MetabID                                        ITHID  \
# 0            OV:P1       P1  GSM642933_OC01_ARN0001_s1h1s1_U133p2.CEL.gz
# 1            OV:P2       P2  GSM642966_OC01_ARN0049_s2h1s1_U133p2.CEL.gz
# 2           OV:P41      P41  GSM642979_OC01_ARN0072_s1h1s1_U133p2.CEL.gz
# 3           OV:P42      P42  GSM643007_OC01_ARN0118_s1h1s1_U133p2.CEL.gz
# 4           OV:P43      P43  GSM642949_OC01_ARN0026_s2h1s1_U133p2.CEL.gz
# ..             ...      ...                                          ...
# 983  LiCa2:LCS_683  LCS_683                    GSM1979661_D6_683A.CEL.gz
# 984  LiCa2:LCS_684  LCS_684                    GSM1979663_B5_684A.CEL.gz
# 985  LiCa2:LCS_685  LCS_685                    GSM1979665_H4_685A.CEL.gz
# 986  LiCa2:LCS_687  LCS_687                    GSM1979667_D6_687A.CEL.gz
# 987  LiCa2:LCS_688  LCS_688                    GSM1979669_F1_688A.CEL.gz
#
#                                            RNAID                  MetabFile  \
# ...

# %%
tpm_rna_files = []
for file_name in list(sample_annot.RNAFile.unique()):
  if file_name.endswith('.tpm.gene_symbol.csv'):
    tpm_rna_files.append(file_name)
tpm_rna_files
# Out:
# ['Flow4Batch.tpm.gene_symbol.csv',
#  'MultiRegionalRCC.tpm.gene_symbol.csv',
#  'Project_08402_M.tpm.gene_symbol.csv',
#  'HCC.tpm.gene_symbol.csv',
#  'Cornell_DLBCL.tpm.gene_symbol.csv',
#  'PMC4187326_BRCA.tpm.gene_symbol.csv',
#  'Multiregions.2Batchs.Sample.hg19KnownGene.tpm.gene_symbol.csv',
#  'CPTAC_GBM_htseq_rna_04_09_2021.tpm.gene_symbol.csv']

# %%
import os

file_names_tpm = []
for file in os.listdir('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/transcriptomics_processed'):
  if file in tpm_rna_files:
    file_names_tpm.append(file)
file_names_tpm
# Out:
# ['CPTAC_GBM_htseq_rna_04_09_2021.tpm.gene_symbol.csv',
#  'Cornell_DLBCL.tpm.gene_symbol.csv',
#  'MultiRegionalRCC.tpm.gene_symbol.csv',
#  'Project_08402_M.tpm.gene_symbol.csv',
#  'Flow4Batch.tpm.gene_symbol.csv',
#  'PMC4187326_BRCA.tpm.gene_symbol.csv',
#  'HCC.tpm.gene_symbol.csv',
#  'Multiregions.2Batchs.Sample.hg19KnownGene.tpm.gene_symbol.csv']

# %%
sample_annot_tpm = sample_annot[sample_annot.RNAFile.isin(file_names_tpm)]
sample_annot_tpm
# Out:
#             CommonID     MetabID    ITHID    RNAID  \
# 45   RC18:MSKC-00397  MSKC-00397   RCC483   RCC483
# 46   RC18:MSKC-00399  MSKC-00399   RCC486   RCC486
# 47   RC18:MSKC-00400  MSKC-00400   RCC495   RCC495
# 48   RC18:MSKC-00404  MSKC-00404   RCC539   RCC539
# 49   RC18:MSKC-00405  MSKC-00405   RCC540   RCC540
# ..               ...         ...      ...      ...
# 843      GBM:PT-P44H     PT-P44H  PT-P44H  PT-P44H
# 844      GBM:PT-R55F     PT-R55F  PT-R55F  PT-R55F
# 845      GBM:PT-RN5K     PT-RN5K  PT-RN5K  PT-RN5K
# 846      GBM:PT-UTHO     PT-UTHO  PT-UTHO  PT-UTHO
# 847      GBM:PT-WVLH     PT-WVLH  PT-WVLH  PT-WVLH
#
#                         MetabFile                 MetabFile_sheet  \
# 45   PreprocessedData_ccRCC2.xlsx   metabo_imputed_filtered_Tumor
# 46   PreprocessedData_ccRCC2.xlsx   metabo_imputed_filtered_Tumor
# 47   PreprocessedData_ccRCC2.xlsx   metabo_imputed_filtered_Tumor
# 48   PreprocessedData_ccRCC2.xlsx   metabo_imputed_filtered_Tumor
# ...

# %%
sample_annot_tpm['SampleID'] = ['Sample_' + str(i) for i in range(len(sample_annot_tpm))]
sample_annot_tpm
# Out:
# /tmp/ipython-input-3994757641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_annot_tpm['SampleID'] = ['Sample_' + str(i) for i in range(len(sample_annot_tpm))]
#             CommonID     MetabID    ITHID    RNAID  \
# 45   RC18:MSKC-00397  MSKC-00397   RCC483   RCC483
# 46   RC18:MSKC-00399  MSKC-00399   RCC486   RCC486
# 47   RC18:MSKC-00400  MSKC-00400   RCC495   RCC495
# 48   RC18:MSKC-00404  MSKC-00404   RCC539   RCC539
# 49   RC18:MSKC-00405  MSKC-00405   RCC540   RCC540
# ..               ...         ...      ...      ...
# 843      GBM:PT-P44H     PT-P44H  PT-P44H  PT-P44H
# 844      GBM:PT-R55F     PT-R55F  PT-R55F  PT-R55F
# 845      GBM:PT-RN5K     PT-RN5K  PT-RN5K  PT-RN5K
# ...

# %%
merged_transcriptomics = pd.DataFrame()
for i in file_names_tpm:
  file_read = pd.read_csv(f'drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/transcriptomics_processed/{i}')
  file_read = file_read.set_index('gene_symbol')
  file_read.index.name = None

  # Check for overlapping columns and only add new ones
  new_cols = [col for col in file_read.columns if col not in merged_transcriptomics.columns]
  merged_transcriptomics = pd.concat([merged_transcriptomics, file_read[new_cols]], axis='columns')

merged_transcriptomics
# Out:
#             C3L-02704   C3N-03180   C3N-03183   C3N-02188   C3N-01851  \
# A1BG         0.634935    0.727131    0.785316    0.505794    0.276903
# A2M        151.737457  147.600144  210.888701  111.010935  235.438260
# A2MP1        0.193512    0.136392    0.140536    0.058927    0.196886
# NAT1         0.079923    0.142145    0.211574    0.138149    0.173220
# NAT2         0.103370    0.047897    0.071581    0.136710    0.221798
# ...               ...         ...         ...         ...         ...
# MAFIP             NaN         NaN         NaN         NaN         NaN
# TP53TG3B          NaN         NaN         NaN         NaN         NaN
# SNAR-A3           NaN         NaN         NaN         NaN         NaN
# MIR4509-1         NaN         NaN         NaN         NaN         NaN
# TTTY8             NaN         NaN         NaN         NaN         NaN
#
#            C3L-03266  C3L-02465   C3N-02788  C3L-01887    PT-Y8DK  ...  \
# ...

# %%
sample_annot_tpm.Dataset.unique()
# Out:
# array(['ccRCC2', 'ccRCC3', 'ccRCC1', 'HurthleCC', 'DLBCL', 'BRCA2',
#        'ccRCC4', 'GBM'], dtype=object)

# %%
file_names_metabolomics = []
for file in os.listdir('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/metabolomics_processed'):
  for dataset in list(sample_annot_tpm.Dataset.unique()):
    if file.endswith(f'{dataset}.xlsx'):
      file_names_metabolomics.append(file)
    else:
      pass
file_names_metabolomics
# Out:
# ['PreprocessedData_BRCA2.xlsx',
#  'PreprocessedData_DLBCL.xlsx',
#  'PreprocessedData_ccRCC2.xlsx',
#  'PreprocessedData_ccRCC1.xlsx',
#  'PreprocessedData_GBM.xlsx',
#  'PreprocessedData_ccRCC3.xlsx',
#  'PreprocessedData_ccRCC4.xlsx',
#  'PreprocessedData_HurthleCC.xlsx']

# %%
file_len = []
for i in file_names_metabolomics:
  file_read = pd.read_excel(f'drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/metabolomics_processed/{i}', sheet_name= 'data_imputed')
  file_len.append(len(file_read))

file_len
# Out:
# [399, 751, 787, 877, 713, 787, 1030, 737]

# %%
merged_metabolomics = pd.DataFrame()
for i in file_names_metabolomics:
  file_read = pd.read_excel(f'drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/pancancer_metabolomics_v.0.3.4/pancancer_metabolomics/data/metabolomics_processed/{i}', sheet_name= 'data_imputed')
  file_read = file_read.set_index('Unnamed: 0')
  file_read.index.name = None

  # Check for overlapping columns and only add new ones
  new_cols = [col for col in file_read.columns if col not in merged_metabolomics.columns]
  merged_metabolomics = pd.concat([merged_metabolomics, file_read[new_cols]], axis='columns')


merged_metabolomics
# Out:
#                               DUKE-00650  DUKE-00651  DUKE-00652  DUKE-00653  \
# 1,2-propanediol                17.728228   21.037723   23.959087   20.682481
# 1,5-anhydroglucitol (1,5-AG)   18.277058   19.394321   19.044231   19.193116
# 1-arachidonoyl-GPC (20:4n6)    16.156080   17.671134   14.631118   15.608743
# 1-arachidonoyl-GPE (20:4n6)    15.611096   14.233610   16.423374   14.400485
# 1-arachidonoyl-GPI (20:4)      15.675876   14.384728   16.305192   15.299840
# ...                                  ...         ...         ...         ...
# nicotinate ribonucleoside            NaN         NaN         NaN         NaN
# norfluoxetine                        NaN         NaN         NaN         NaN
# palmitoleoyl ethanolamide            NaN         NaN         NaN         NaN
# succinimide                          NaN         NaN         NaN         NaN
# thyroxine                            NaN         NaN         NaN         NaN
#
# ...

# %%
merged_transcriptomics = merged_transcriptomics[sample_annot_tpm.RNAID]
merged_transcriptomics
# Out:
#                RCC483      RCC486      RCC495      RCC539       RCC540  \
# A1BG         1.304026    1.928762    0.869958    1.880487     1.660118
# A2M        320.190822  599.699496  759.630310  530.494017  1391.019172
# A2MP1        4.301926    1.251719    1.620558    1.792046     1.391611
# NAT1         8.314472   10.039836    5.763073    8.030295     4.538719
# NAT2         0.964676    3.234161    0.369455    0.605261     0.396575
# ...               ...         ...         ...         ...          ...
# MAFIP             NaN         NaN         NaN         NaN          NaN
# TP53TG3B          NaN         NaN         NaN         NaN          NaN
# SNAR-A3           NaN         NaN         NaN         NaN          NaN
# MIR4509-1         NaN         NaN         NaN         NaN          NaN
# TTTY8             NaN         NaN         NaN         NaN          NaN
#
#                RCC542     RCC547       RCC560      RCC564      RCC575  ...  \
# ...

# %%
sample_annot_tpm_to_metabolomic = {}
for i in sample_annot_tpm.RNAID:
  metabid = sample_annot_tpm[sample_annot_tpm['RNAID'] == i].MetabID.values[0]
  sample_annot_tpm_to_metabolomic[i] = metabid
len(sample_annot_tpm_to_metabolomic)
# Out:
# 443

# %%
merged_transcriptomics.columns = [sample_annot_tpm_to_metabolomic[i] for i in merged_transcriptomics.columns]
merged_transcriptomics
# Out:
#            MSKC-00397  MSKC-00399  MSKC-00400  MSKC-00404   MSKC-00405  \
# A1BG         1.304026    1.928762    0.869958    1.880487     1.660118
# A2M        320.190822  599.699496  759.630310  530.494017  1391.019172
# A2MP1        4.301926    1.251719    1.620558    1.792046     1.391611
# NAT1         8.314472   10.039836    5.763073    8.030295     4.538719
# NAT2         0.964676    3.234161    0.369455    0.605261     0.396575
# ...               ...         ...         ...         ...          ...
# MAFIP             NaN         NaN         NaN         NaN          NaN
# TP53TG3B          NaN         NaN         NaN         NaN          NaN
# SNAR-A3           NaN         NaN         NaN         NaN          NaN
# MIR4509-1         NaN         NaN         NaN         NaN          NaN
# TTTY8             NaN         NaN         NaN         NaN          NaN
#
#            MSKC-00406  MSKC-00407   MSKC-00412  MSKC-00441  MSKC-00417  ...  \
# ...

# %%
common_samples = []
for i in merged_metabolomics.columns:
  if i in merged_transcriptomics.columns:
    common_samples.append(i)
  else:
    pass
len(common_samples)
# Out:
# 443

# %%
merged_transcriptomics_common =  merged_transcriptomics[common_samples]
merged_transcriptomics_common
# Out:
#            DUKE-00651  DUKE-00652  DUKE-00653  DUKE-00654  DUKE-00657  \
# A1BG         8.419442    5.732535   10.671391    5.782269   10.816996
# A2M        176.202102  179.717662  101.369695  137.234012  441.394275
# A2MP1        0.056236    0.026734    0.033223    0.168227    0.402998
# NAT1       144.514353   57.145670  356.324843   14.810037   72.763636
# NAT2         0.564116    0.950776    0.454457    0.230115    1.102507
# ...               ...         ...         ...         ...         ...
# MAFIP        2.645171    2.364895    2.599040    3.047131    4.835349
# TP53TG3B     0.000000    0.000000    0.000000    0.000000    0.000000
# SNAR-A3           NaN         NaN         NaN         NaN         NaN
# MIR4509-1         NaN         NaN         NaN         NaN         NaN
# TTTY8             NaN         NaN         NaN         NaN         NaN
#
#            DUKE-00658  DUKE-00660   DUKE-00662  DUKE-00665  DUKE-00666  ...  \
# ...

# %%
merged_metabolomics_common =  merged_metabolomics[common_samples]
merged_metabolomics_common
# Out:
#                               DUKE-00651  DUKE-00652  DUKE-00653  DUKE-00654  \
# 1,2-propanediol                21.037723   23.959087   20.682481   19.963768
# 1,5-anhydroglucitol (1,5-AG)   19.394321   19.044231   19.193116   19.653941
# 1-arachidonoyl-GPC (20:4n6)    17.671134   14.631118   15.608743   15.383235
# 1-arachidonoyl-GPE (20:4n6)    14.233610   16.423374   14.400485   15.369813
# 1-arachidonoyl-GPI (20:4)      14.384728   16.305192   15.299840   14.913759
# ...                                  ...         ...         ...         ...
# nicotinate ribonucleoside            NaN         NaN         NaN         NaN
# norfluoxetine                        NaN         NaN         NaN         NaN
# palmitoleoyl ethanolamide            NaN         NaN         NaN         NaN
# succinimide                          NaN         NaN         NaN         NaN
# thyroxine                            NaN         NaN         NaN         NaN
#
# ...

# %%
merged_transcriptomics_common.to_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/transcriptomics_tpm.csv', index = True)

# %%
merged_metabolomics_common.to_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/metabolomics_log2.csv', index = True)

# %%
met_genes = pd.read_csv('drive/My Drive/Colab Notebooks/GP_lab_data/FBA_metabolic_atlas_models/human_gem_associated_genes.csv')
met_genes
# Out:
#               gene_id   Symbol
# 0     ENSG00000198712   MT-CO2
# 1     ENSG00000198804   MT-CO1
# 2     ENSG00000198938   MT-CO3
# 3     ENSG00000198899  MT-ATP6
# 4     ENSG00000198886   MT-ND4
# ...               ...      ...
# 2879  ENSG00000167751     KLK2
# 2880  ENSG00000129873    CDY2B
# 2881  ENSG00000182415    CDY2A
# 2882  ENSG00000172352    CDY1B
# 2883  ENSG00000172288     CDY1
#
# [2884 rows x 2 columns]

# %%
tpm_met = merged_transcriptomics_common[merged_transcriptomics_common.index.isin(met_genes['Symbol'])]
tpm_met
# Out:
#            DUKE-00651  DUKE-00652   DUKE-00653  DUKE-00654  DUKE-00657  \
# NAT1       144.514353   57.145670   356.324843   14.810037   72.763636
# NAT2         0.564116    0.950776     0.454457    0.230115    1.102507
# SERPINA3  1879.323517  169.911831  2776.507016  849.949951  345.895191
# AADAC        2.607398    0.039984     0.248451    0.000000    0.452055
# AANAT        0.000000    0.074702     0.000000    0.094016    0.090088
# ...               ...         ...          ...         ...         ...
# AK6               NaN         NaN          NaN         NaN         NaN
# TREX1        0.202337    0.028856     0.083676    0.166451    0.057999
# PGAM2        7.486934   10.340171    62.063505   80.097260   13.497796
# CEMP1        5.210511    5.140856     5.866129   13.270873    6.234940
# CDY2A             NaN         NaN          NaN         NaN         NaN
#
#           DUKE-00658  DUKE-00660  DUKE-00662  DUKE-00665  DUKE-00666  ...  \
# ...

# %%
tpm_met.to_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/transcriptomics_tpm_metabolism_related_genes.csv', index = True)

# %%
merged_transcriptomics.to_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/transcriptomics_tpm_benedetti.csv', index = True)

# %%
tpm_met_ensembl_id = merged_transcriptomics_common.T.reindex(met_genes['Symbol'], axis = 'columns')
tpm_met_ensembl_id.columns.name = None
tpm_met_ensembl_id
# Out:
#             MT-CO2  MT-CO1  MT-CO3  MT-ATP6  MT-ND4  MT-ND4L  MT-ND2  MT-ND3  \
# DUKE-00651     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# DUKE-00652     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# DUKE-00653     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# DUKE-00654     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# DUKE-00657     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# ...            ...     ...     ...      ...     ...      ...     ...     ...
# MSKC-00483     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# MSKC-00484     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# MSKC-00485     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# MSKC-00486     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# MSKC-00487     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
# ...

# %%
met_genes_dict = dict(zip(met_genes['Symbol'], met_genes['gene_id']))
len(met_genes_dict) == len(met_genes)
# Out:
# True

# %%
tpm_met_ensembl_id = tpm_met_ensembl_id.rename(columns = met_genes_dict).T
tpm_met_ensembl_id.index.name = None
tpm_met_ensembl_id = tpm_met_ensembl_id.dropna(how = 'all', axis = 'index')
tpm_met_ensembl_id
# Out:
#                  DUKE-00651  DUKE-00652  DUKE-00653  DUKE-00654  DUKE-00657  \
# ENSG00000198712         NaN         NaN         NaN         NaN         NaN
# ENSG00000198804         NaN         NaN         NaN         NaN         NaN
# ENSG00000198938         NaN         NaN         NaN         NaN         NaN
# ENSG00000198899         NaN         NaN         NaN         NaN         NaN
# ENSG00000198886         NaN         NaN         NaN         NaN         NaN
# ...                     ...         ...         ...         ...         ...
# ENSG00000182156    0.000000    0.000000    0.064986         0.0    0.026276
# ENSG00000166948    0.000000    0.000000    0.000000         0.0    0.000000
# ENSG00000197838    0.038375    0.036485    0.022671         0.0    0.000000
# ENSG00000167751    0.060810    0.298714    0.431106         0.0    0.145258
# ENSG00000182415         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
tpm_met_ensembl_id.to_csv('drive/My Drive/Colab Notebooks/Metabolite_prediction_ML/transcriptomics_tpm_metabolism_related_genes_ensembl_id.csv', index = True)
